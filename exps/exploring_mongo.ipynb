# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, "../common/")
import mongo_helper_functions as mongo_helper
# from mongo_helper_functions import *
# from encoding_cascade_functions import *
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tweets = mongo_helper.connectMongo(
    host= "angst.soic.indiana.edu",
    db_name= "smm4h",
    collection_name= "tweets"
)
tweets.estimated_document_count()
# Out:
# 23965

# %%
df = mongo_helper.query(
    tweets,
    mongo_helper.limit(10)
)
df.info()
df
# Out:
# INFO:root:Query duration: 0:00:00.101707
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 54 columns):
# _id                                     10 non-null object
# datetime                                10 non-null datetime64[ns]
# task_four                               10 non-null bool
# task_one                                10 non-null bool
# task_three                              10 non-null bool
# task_two                                10 non-null bool
# tweet.coordinates                       0 non-null object
# tweet.created_at                        10 non-null object
# tweet.entities.hashtags                 10 non-null object
# tweet.entities.symbols                  10 non-null object
# tweet.entities.urls                     10 non-null object
# tweet.entities.user_mentions            10 non-null object
# tweet.favorite_count                    10 non-null int64
# ...
